# %%
from sklearn.datasets import load_iris
iris = load_iris()

print (iris.feature_names)
print (iris.target_names)
print (iris.data[0])
print (iris.target[0])

for i in range(len(iris.target)):
               print ("Example %d : labels %s : features %s" %(i , iris.target[i],iris.data[i]))
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']
# [ 5.1  3.5  1.4  0.2]
# 0
# Example 0 : labels 0 : features [ 5.1  3.5  1.4  0.2]
# Example 1 : labels 0 : features [ 4.9  3.   1.4  0.2]
# Example 2 : labels 0 : features [ 4.7  3.2  1.3  0.2]
# Example 3 : labels 0 : features [ 4.6  3.1  1.5  0.2]
# Example 4 : labels 0 : features [ 5.   3.6  1.4  0.2]
# Example 5 : labels 0 : features [ 5.4  3.9  1.7  0.4]
# Example 6 : labels 0 : features [ 4.6  3.4  1.4  0.3]
# Example 7 : labels 0 : features [ 5.   3.4  1.5  0.2]
# Example 8 : labels 0 : features [ 4.4  2.9  1.4  0.2]
# Example 9 : labels 0 : features [ 4.9  3.1  1.5  0.1]
# Example 10 : labels 0 : features [ 5.4  3.7  1.5  0.2]
# Example 11 : labels 0 : features [ 4.8  3.4  1.6  0.2]
# Example 12 : labels 0 : features [ 4.8  3.   1.4  0.1]
# Example 13 : labels 0 : features [ 4.3  3.   1.1  0.1]
# Example 14 : labels 0 : features [ 5.8  4.   1.2  0.2]
# Example 15 : labels 0 : features [ 5.7  4.4  1.5  0.4]
# Example 16 : labels 0 : features [ 5.4  3.9  1.3  0.4]
# Example 17 : labels 0 : features [ 5.1  3.5  1.4  0.3]
# Example 18 : labels 0 : features [ 5.7  3.8  1.7  0.3]
# Example 19 : labels 0 : features [ 5.1  3.8  1.5  0.3]
# Example 20 : labels 0 : features [ 5.4  3.4  1.7  0.2]
# Example 21 : labels 0 : features [ 5.1  3.7  1.5  0.4]
# Example 22 : labels 0 : features [ 4.6  3.6  1.   0.2]
# Example 23 : labels 0 : features [ 5.1  3.3  1.7  0.5]
# Example 24 : labels 0 : features [ 4.8  3.4  1.9  0.2]
# Example 25 : labels 0 : features [ 5.   3.   1.6  0.2]
# Example 26 : labels 0 : features [ 5.   3.4  1.6  0.4]
# Example 27 : labels 0 : features [ 5.2  3.5  1.5  0.2]
# Example 28 : labels 0 : features [ 5.2  3.4  1.4  0.2]
# Example 29 : labels 0 : features [ 4.7  3.2  1.6  0.2]
# Example 30 : labels 0 : features [ 4.8  3.1  1.6  0.2]
# Example 31 : labels 0 : features [ 5.4  3.4  1.5  0.4]
# Example 32 : labels 0 : features [ 5.2  4.1  1.5  0.1]
# Example 33 : labels 0 : features [ 5.5  4.2  1.4  0.2]
# Example 34 : labels 0 : features [ 4.9  3.1  1.5  0.1]
# Example 35 : labels 0 : features [ 5.   3.2  1.2  0.2]
# Example 36 : labels 0 : features [ 5.5  3.5  1.3  0.2]
# Example 37 : labels 0 : features [ 4.9  3.1  1.5  0.1]
# Example 38 : labels 0 : features [ 4.4  3.   1.3  0.2]
# Example 39 : labels 0 : features [ 5.1  3.4  1.5  0.2]
# Example 40 : labels 0 : features [ 5.   3.5  1.3  0.3]
# Example 41 : labels 0 : features [ 4.5  2.3  1.3  0.3]
# Example 42 : labels 0 : features [ 4.4  3.2  1.3  0.2]
# Example 43 : labels 0 : features [ 5.   3.5  1.6  0.6]
# Example 44 : labels 0 : features [ 5.1  3.8  1.9  0.4]
# Example 45 : labels 0 : features [ 4.8  3.   1.4  0.3]
# Example 46 : labels 0 : features [ 5.1  3.8  1.6  0.2]
# Example 47 : labels 0 : features [ 4.6  3.2  1.4  0.2]
# Example 48 : labels 0 : features [ 5.3  3.7  1.5  0.2]
# Example 49 : labels 0 : features [ 5.   3.3  1.4  0.2]
# Example 50 : labels 1 : features [ 7.   3.2  4.7  1.4]
# Example 51 : labels 1 : features [ 6.4  3.2  4.5  1.5]
# Example 52 : labels 1 : features [ 6.9  3.1  4.9  1.5]
# Example 53 : labels 1 : features [ 5.5  2.3  4.   1.3]
# Example 54 : labels 1 : features [ 6.5  2.8  4.6  1.5]
# Example 55 : labels 1 : features [ 5.7  2.8  4.5  1.3]
# Example 56 : labels 1 : features [ 6.3  3.3  4.7  1.6]
# Example 57 : labels 1 : features [ 4.9  2.4  3.3  1. ]
# Example 58 : labels 1 : features [ 6.6  2.9  4.6  1.3]
# Example 59 : labels 1 : features [ 5.2  2.7  3.9  1.4]
# Example 60 : labels 1 : features [ 5.   2.   3.5  1. ]
# Example 61 : labels 1 : features [ 5.9  3.   4.2  1.5]
# Example 62 : labels 1 : features [ 6.   2.2  4.   1. ]
# Example 63 : labels 1 : features [ 6.1  2.9  4.7  1.4]
# Example 64 : labels 1 : features [ 5.6  2.9  3.6  1.3]
# Example 65 : labels 1 : features [ 6.7  3.1  4.4  1.4]
# Example 66 : labels 1 : features [ 5.6  3.   4.5  1.5]
# Example 67 : labels 1 : features [ 5.8  2.7  4.1  1. ]
# Example 68 : labels 1 : features [ 6.2  2.2  4.5  1.5]
# Example 69 : labels 1 : features [ 5.6  2.5  3.9  1.1]
# Example 70 : labels 1 : features [ 5.9  3.2  4.8  1.8]
# Example 71 : labels 1 : features [ 6.1  2.8  4.   1.3]
# Example 72 : labels 1 : features [ 6.3  2.5  4.9  1.5]
# Example 73 : labels 1 : features [ 6.1  2.8  4.7  1.2]
# Example 74 : labels 1 : features [ 6.4  2.9  4.3  1.3]
# Example 75 : labels 1 : features [ 6.6  3.   4.4  1.4]
# Example 76 : labels 1 : features [ 6.8  2.8  4.8  1.4]
# Example 77 : labels 1 : features [ 6.7  3.   5.   1.7]
# Example 78 : labels 1 : features [ 6.   2.9  4.5  1.5]
# Example 79 : labels 1 : features [ 5.7  2.6  3.5  1. ]
# Example 80 : labels 1 : features [ 5.5  2.4  3.8  1.1]
# Example 81 : labels 1 : features [ 5.5  2.4  3.7  1. ]
# Example 82 : labels 1 : features [ 5.8  2.7  3.9  1.2]
# Example 83 : labels 1 : features [ 6.   2.7  5.1  1.6]
# Example 84 : labels 1 : features [ 5.4  3.   4.5  1.5]
# Example 85 : labels 1 : features [ 6.   3.4  4.5  1.6]
# Example 86 : labels 1 : features [ 6.7  3.1  4.7  1.5]
# Example 87 : labels 1 : features [ 6.3  2.3  4.4  1.3]
# Example 88 : labels 1 : features [ 5.6  3.   4.1  1.3]
# Example 89 : labels 1 : features [ 5.5  2.5  4.   1.3]
# Example 90 : labels 1 : features [ 5.5  2.6  4.4  1.2]
# Example 91 : labels 1 : features [ 6.1  3.   4.6  1.4]
# Example 92 : labels 1 : features [ 5.8  2.6  4.   1.2]
# Example 93 : labels 1 : features [ 5.   2.3  3.3  1. ]
# Example 94 : labels 1 : features [ 5.6  2.7  4.2  1.3]
# Example 95 : labels 1 : features [ 5.7  3.   4.2  1.2]
# Example 96 : labels 1 : features [ 5.7  2.9  4.2  1.3]
# Example 97 : labels 1 : features [ 6.2  2.9  4.3  1.3]
# Example 98 : labels 1 : features [ 5.1  2.5  3.   1.1]
# Example 99 : labels 1 : features [ 5.7  2.8  4.1  1.3]
# Example 100 : labels 2 : features [ 6.3  3.3  6.   2.5]
# Example 101 : labels 2 : features [ 5.8  2.7  5.1  1.9]
# Example 102 : labels 2 : features [ 7.1  3.   5.9  2.1]
# Example 103 : labels 2 : features [ 6.3  2.9  5.6  1.8]
# Example 104 : labels 2 : features [ 6.5  3.   5.8  2.2]
# Example 105 : labels 2 : features [ 7.6  3.   6.6  2.1]
# Example 106 : labels 2 : features [ 4.9  2.5  4.5  1.7]
# Example 107 : labels 2 : features [ 7.3  2.9  6.3  1.8]
# Example 108 : labels 2 : features [ 6.7  2.5  5.8  1.8]
# Example 109 : labels 2 : features [ 7.2  3.6  6.1  2.5]
# Example 110 : labels 2 : features [ 6.5  3.2  5.1  2. ]
# Example 111 : labels 2 : features [ 6.4  2.7  5.3  1.9]
# Example 112 : labels 2 : features [ 6.8  3.   5.5  2.1]
# Example 113 : labels 2 : features [ 5.7  2.5  5.   2. ]
# Example 114 : labels 2 : features [ 5.8  2.8  5.1  2.4]
# Example 115 : labels 2 : features [ 6.4  3.2  5.3  2.3]
# Example 116 : labels 2 : features [ 6.5  3.   5.5  1.8]
# Example 117 : labels 2 : features [ 7.7  3.8  6.7  2.2]
# Example 118 : labels 2 : features [ 7.7  2.6  6.9  2.3]
# Example 119 : labels 2 : features [ 6.   2.2  5.   1.5]
# Example 120 : labels 2 : features [ 6.9  3.2  5.7  2.3]
# Example 121 : labels 2 : features [ 5.6  2.8  4.9  2. ]
# Example 122 : labels 2 : features [ 7.7  2.8  6.7  2. ]
# Example 123 : labels 2 : features [ 6.3  2.7  4.9  1.8]
# Example 124 : labels 2 : features [ 6.7  3.3  5.7  2.1]
# Example 125 : labels 2 : features [ 7.2  3.2  6.   1.8]
# Example 126 : labels 2 : features [ 6.2  2.8  4.8  1.8]
# Example 127 : labels 2 : features [ 6.1  3.   4.9  1.8]
# Example 128 : labels 2 : features [ 6.4  2.8  5.6  2.1]
# Example 129 : labels 2 : features [ 7.2  3.   5.8  1.6]
# Example 130 : labels 2 : features [ 7.4  2.8  6.1  1.9]
# Example 131 : labels 2 : features [ 7.9  3.8  6.4  2. ]
# Example 132 : labels 2 : features [ 6.4  2.8  5.6  2.2]
# Example 133 : labels 2 : features [ 6.3  2.8  5.1  1.5]
# Example 134 : labels 2 : features [ 6.1  2.6  5.6  1.4]
# Example 135 : labels 2 : features [ 7.7  3.   6.1  2.3]
# Example 136 : labels 2 : features [ 6.3  3.4  5.6  2.4]
# Example 137 : labels 2 : features [ 6.4  3.1  5.5  1.8]
# Example 138 : labels 2 : features [ 6.   3.   4.8  1.8]
# Example 139 : labels 2 : features [ 6.9  3.1  5.4  2.1]
# Example 140 : labels 2 : features [ 6.7  3.1  5.6  2.4]
# Example 141 : labels 2 : features [ 6.9  3.1  5.1  2.3]
# Example 142 : labels 2 : features [ 5.8  2.7  5.1  1.9]
# Example 143 : labels 2 : features [ 6.8  3.2  5.9  2.3]
# Example 144 : labels 2 : features [ 6.7  3.3  5.7  2.5]
# Example 145 : labels 2 : features [ 6.7  3.   5.2  2.3]
# Example 146 : labels 2 : features [ 6.3  2.5  5.   1.9]
# Example 147 : labels 2 : features [ 6.5  3.   5.2  2. ]
# Example 148 : labels 2 : features [ 6.2  3.4  5.4  2.3]
# Example 149 : labels 2 : features [ 5.9  3.   5.1  1.8]
