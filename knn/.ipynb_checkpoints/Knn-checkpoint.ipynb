# %%
import numpy as np
import pandas as pd
import math 
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets
import itertools


# import some data to play with


def loadData(fileName):
    df = pd.read_csv(fileName,sep=',',header=None)
    X = df[df.columns[0:8]]
    y = df[8]
    return X.values , y.values



def eculidenDistance(x , xi):
    d = 0.0
    for i in range(len(x)):
        d += pow(abs(x[i]-xi[i]),2)
    return math.sqrt(d)


def getKey(item):
    return item[1]

def knnPredictor(train,test,k):
    X = train[0]
    y = train[1]
    Xt = test[0]
    yt = test[1]
    #each record will be index of training data &  distance between new record and record[i] in the training
    #[i,distance[i]]
    
    cnt = 0
    for i in range(len(Xt)):
        newDataSet = []
        for j in range(len(X)):
            newDataSet.append([j,eculidenDistance(X[j],Xt[i]),y[j]])
            
        newDataSet = sorted(newDataSet,key=getKey)
        dict = {}
        keyOfMaxItem = ''
        for item in itertools.islice(newDataSet , 0, k):
            key = item[2]
            keyOfMaxItem = key
            if key in dict:
                dict[key] = dict[key] + 1
            else:
                dict[key] = 1

        for key in dict:
            if dict[key] >= dict[keyOfMaxItem]:
                keyOfMaxItem = key
        if keyOfMaxItem == yt[i]:
            cnt += 1
        print("Predicted class: ", keyOfMaxItem ,dict[keyOfMaxItem] ," - Actual Class: ", yt[i])
    
    accuracy = (float(cnt)/len(Xt))*100
    
    print(cnt)
    print(len(Xt))
    print(accuracy)


X , y = loadData('TrainData.txt')
Xt , yt = loadData('TestData.txt')
print(len(y))

n_neighbors = 3

knnPredictor([X,y],[Xt,yt],n_neighbors)
# Out:
# 1039
# Predicted class:  POX 3  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  NUC 3  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  MIT 1  - Actual Class:  NUC
# Predicted class:  EXC 2  - Actual Class:  CYT
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  MIT 2  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  MIT
# Predicted class:  ME1 3  - Actual Class:  ME1
# Predicted class:  ME1 3  - Actual Class:  ME1
# Predicted class:  MIT 1  - Actual Class:  MIT
# Predicted class:  CYT 2  - Actual Class:  MIT
# Predicted class:  ME1 1  - Actual Class:  ME2
# Predicted class:  NUC 1  - Actual Class:  CYT
# Predicted class:  NUC 3  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  MIT 2  - Actual Class:  MIT
# Predicted class:  MIT 1  - Actual Class:  NUC
# Predicted class:  ME3 2  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  MIT 1  - Actual Class:  CYT
# Predicted class:  ME1 2  - Actual Class:  EXC
# Predicted class:  MIT 2  - Actual Class:  MIT
# Predicted class:  MIT 2  - Actual Class:  MIT
# Predicted class:  MIT 2  - Actual Class:  MIT
# Predicted class:  POX 2  - Actual Class:  MIT
# Predicted class:  ME3 3  - Actual Class:  ME3
# Predicted class:  NUC 1  - Actual Class:  CYT
# Predicted class:  ME1 2  - Actual Class:  MIT
# Predicted class:  ME3 3  - Actual Class:  ME3
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  CYT 1  - Actual Class:  CYT
# Predicted class:  POX 2  - Actual Class:  POX
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  MIT 2  - Actual Class:  MIT
# Predicted class:  CYT 3  - Actual Class:  MIT
# Predicted class:  EXC 2  - Actual Class:  MIT
# Predicted class:  ME3 3  - Actual Class:  ME3
# Predicted class:  NUC 3  - Actual Class:  NUC
# Predicted class:  NUC 3  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  MIT 1  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  NUC 3  - Actual Class:  NUC
# Predicted class:  CYT 1  - Actual Class:  CYT
# Predicted class:  NUC 3  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  CYT 1  - Actual Class:  NUC
# Predicted class:  MIT 3  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  POX 2  - Actual Class:  POX
# Predicted class:  NUC 3  - Actual Class:  NUC
# Predicted class:  CYT 1  - Actual Class:  CYT
# Predicted class:  ME1 3  - Actual Class:  ME1
# Predicted class:  ME1 1  - Actual Class:  MIT
# Predicted class:  MIT 2  - Actual Class:  MIT
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  ME3 2  - Actual Class:  MIT
# Predicted class:  MIT 2  - Actual Class:  MIT
# Predicted class:  MIT 2  - Actual Class:  MIT
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  CYT 2  - Actual Class:  MIT
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  EXC 2  - Actual Class:  EXC
# Predicted class:  CYT 1  - Actual Class:  VAC
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  MIT 1  - Actual Class:  ME2
# Predicted class:  CYT 3  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  EXC 2  - Actual Class:  EXC
# Predicted class:  EXC 2  - Actual Class:  EXC
# Predicted class:  CYT 3  - Actual Class:  MIT
# Predicted class:  CYT 3  - Actual Class:  MIT
# Predicted class:  CYT 2  - Actual Class:  MIT
# Predicted class:  CYT 2  - Actual Class:  MIT
# Predicted class:  ME3 3  - Actual Class:  ME3
# Predicted class:  POX 2  - Actual Class:  POX
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  NUC 3  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  ME2
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  ME3
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  ME3 3  - Actual Class:  ME3
# Predicted class:  NUC 3  - Actual Class:  CYT
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  ME1 1  - Actual Class:  ME2
# Predicted class:  ME2 1  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  ME3 1  - Actual Class:  ME2
# Predicted class:  MIT 3  - Actual Class:  ME3
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  ME1 2  - Actual Class:  EXC
# Predicted class:  ME3 1  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  ME3 2  - Actual Class:  ME3
# Predicted class:  VAC 2  - Actual Class:  ME3
# Predicted class:  POX 2  - Actual Class:  POX
# Predicted class:  ME3 3  - Actual Class:  ME3
# Predicted class:  ME2 2  - Actual Class:  ME1
# Predicted class:  ME1 3  - Actual Class:  ME2
# Predicted class:  VAC 1  - Actual Class:  CYT
# Predicted class:  ME3 3  - Actual Class:  ME3
# Predicted class:  ME3 3  - Actual Class:  ME3
# Predicted class:  MIT 3  - Actual Class:  ME1
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  ME3 3  - Actual Class:  ME3
# Predicted class:  NUC 3  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  CYT 3  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  VAC 2  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  NUC 3  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  VAC 1  - Actual Class:  ME2
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  NUC 3  - Actual Class:  NUC
# Predicted class:  MIT 2  - Actual Class:  MIT
# Predicted class:  NUC 1  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  CYT 3  - Actual Class:  NUC
# Predicted class:  NUC 3  - Actual Class:  CYT
# Predicted class:  MIT 2  - Actual Class:  MIT
# Predicted class:  NUC 3  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  NUC 1  - Actual Class:  NUC
# Predicted class:  NUC 1  - Actual Class:  NUC
# Predicted class:  MIT 2  - Actual Class:  NUC
# Predicted class:  MIT 2  - Actual Class:  NUC
# Predicted class:  ME3 3  - Actual Class:  ME3
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  MIT 2  - Actual Class:  MIT
# Predicted class:  MIT 2  - Actual Class:  MIT
# Predicted class:  CYT 1  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  ME3 3  - Actual Class:  ME3
# Predicted class:  ME3 3  - Actual Class:  ME3
# Predicted class:  POX 1  - Actual Class:  POX
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  CYT 3  - Actual Class:  MIT
# Predicted class:  CYT 1  - Actual Class:  MIT
# Predicted class:  ME1 2  - Actual Class:  ME1
# Predicted class:  CYT 2  - Actual Class:  ME3
# Predicted class:  MIT 2  - Actual Class:  CYT
# Predicted class:  MIT 2  - Actual Class:  MIT
# Predicted class:  ME2 2  - Actual Class:  EXC
# Predicted class:  NUC 3  - Actual Class:  ME3
# Predicted class:  ME2 1  - Actual Class:  CYT
# Predicted class:  MIT 2  - Actual Class:  CYT
# Predicted class:  ME3 3  - Actual Class:  ME3
# Predicted class:  EXC 1  - Actual Class:  ME2
# Predicted class:  ME2 2  - Actual Class:  ME2
# Predicted class:  ME2 1  - Actual Class:  VAC
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  ME3 2  - Actual Class:  ME3
# Predicted class:  NUC 2  - Actual Class:  ME3
# Predicted class:  ME2 2  - Actual Class:  ME2
# Predicted class:  NUC 3  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  NUC 3  - Actual Class:  NUC
# Predicted class:  ME3 2  - Actual Class:  ME3
# Predicted class:  ME2 2  - Actual Class:  MIT
# Predicted class:  CYT 3  - Actual Class:  MIT
# Predicted class:  CYT 2  - Actual Class:  MIT
# Predicted class:  MIT 2  - Actual Class:  CYT
# Predicted class:  NUC 1  - Actual Class:  MIT
# Predicted class:  ME3 1  - Actual Class:  ME3
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  NUC 1  - Actual Class:  NUC
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  ME3 3  - Actual Class:  ME3
# Predicted class:  NUC 3  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  ME3 1  - Actual Class:  MIT
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  CYT 2  - Actual Class:  MIT
# Predicted class:  NUC 1  - Actual Class:  MIT
# Predicted class:  CYT 3  - Actual Class:  MIT
# Predicted class:  NUC 2  - Actual Class:  MIT
# Predicted class:  NUC 1  - Actual Class:  MIT
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  ME2 1  - Actual Class:  NUC
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  NUC 3  - Actual Class:  NUC
# Predicted class:  EXC 1  - Actual Class:  MIT
# Predicted class:  MIT 2  - Actual Class:  MIT
# Predicted class:  CYT 2  - Actual Class:  MIT
# Predicted class:  MIT 2  - Actual Class:  EXC
# Predicted class:  ME3 3  - Actual Class:  ME3
# Predicted class:  MIT 2  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  ME2 1  - Actual Class:  ME2
# Predicted class:  ME3 2  - Actual Class:  NUC
# Predicted class:  MIT 3  - Actual Class:  NUC
# Predicted class:  NUC 3  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  EXC 1  - Actual Class:  NUC
# Predicted class:  NUC 3  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  MIT 1  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  MIT 3  - Actual Class:  ME2
# Predicted class:  ME3 3  - Actual Class:  ME2
# Predicted class:  ME2 2  - Actual Class:  MIT
# Predicted class:  CYT 2  - Actual Class:  MIT
# Predicted class:  NUC 2  - Actual Class:  MIT
# Predicted class:  CYT 2  - Actual Class:  POX
# Predicted class:  MIT 3  - Actual Class:  POX
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  ME3 2  - Actual Class:  ME3
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  NUC 1  - Actual Class:  VAC
# Predicted class:  CYT 2  - Actual Class:  VAC
# Predicted class:  NUC 1  - Actual Class:  MIT
# Predicted class:  CYT 2  - Actual Class:  MIT
# Predicted class:  POX 2  - Actual Class:  MIT
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  EXC 3  - Actual Class:  EXC
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  CYT 3  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 3  - Actual Class:  ME3
# Predicted class:  EXC 2  - Actual Class:  ME1
# Predicted class:  ME2 2  - Actual Class:  ME2
# Predicted class:  ME3 2  - Actual Class:  ME3
# Predicted class:  CYT 1  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  MIT 1  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  ME3 3  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  ME2 2  - Actual Class:  ME3
# Predicted class:  CYT 2  - Actual Class:  MIT
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  MIT 3  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  MIT 1  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  NUC 3  - Actual Class:  NUC
# Predicted class:  MIT 1  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 3  - Actual Class:  MIT
# Predicted class:  ME2 2  - Actual Class:  MIT
# Predicted class:  CYT 3  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  MIT 3  - Actual Class:  NUC
# Predicted class:  NUC 3  - Actual Class:  NUC
# Predicted class:  NUC 3  - Actual Class:  NUC
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  NUC 3  - Actual Class:  NUC
# Predicted class:  NUC 1  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 1  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  MIT 2  - Actual Class:  CYT
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 3  - Actual Class:  NUC
# Predicted class:  CYT 3  - Actual Class:  NUC
# Predicted class:  MIT 1  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  VAC 1  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  POX 1  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  MIT 2  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  MIT 2  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  MIT 2  - Actual Class:  CYT
# Predicted class:  MIT 2  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  MIT 1  - Actual Class:  MIT
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  ME1 1  - Actual Class:  ME1
# Predicted class:  CYT 3  - Actual Class:  ME2
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  MIT 2  - Actual Class:  CYT
# Predicted class:  ME3 2  - Actual Class:  ME3
# Predicted class:  ME3 2  - Actual Class:  ME2
# Predicted class:  NUC 2  - Actual Class:  MIT
# Predicted class:  ME1 2  - Actual Class:  ME1
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  MIT 2  - Actual Class:  MIT
# Predicted class:  MIT 2  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  ME3 3  - Actual Class:  ME3
# Predicted class:  NUC 1  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  ME3
# Predicted class:  NUC 1  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  MIT 2  - Actual Class:  CYT
# Predicted class:  ME3 3  - Actual Class:  ME3
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  ME3 2  - Actual Class:  ME3
# Predicted class:  MIT 2  - Actual Class:  MIT
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  MIT 2  - Actual Class:  NUC
# Predicted class:  CYT 3  - Actual Class:  NUC
# Predicted class:  MIT 2  - Actual Class:  NUC
# Predicted class:  NUC 3  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  MIT 3  - Actual Class:  MIT
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  ME3
# Predicted class:  ME3 2  - Actual Class:  ME3
# Predicted class:  EXC 2  - Actual Class:  EXC
# Predicted class:  ME3 2  - Actual Class:  ME3
# Predicted class:  ME1 2  - Actual Class:  ME1
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  MIT 1  - Actual Class:  MIT
# Predicted class:  NUC 3  - Actual Class:  NUC
# Predicted class:  CYT 1  - Actual Class:  CYT
# Predicted class:  EXC 2  - Actual Class:  EXC
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  NUC 1  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  NUC 3  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  NUC 1  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  MIT 2  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  NUC 3  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  ME1 2  - Actual Class:  ME1
# Predicted class:  ME1 2  - Actual Class:  ME1
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  NUC 3  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  NUC 1  - Actual Class:  CYT
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  MIT 2  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  NUC 2  - Actual Class:  CYT
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  ME3 2  - Actual Class:  ME3
# Predicted class:  CYT 2  - Actual Class:  CYT
# Predicted class:  NUC 2  - Actual Class:  NUC
# Predicted class:  CYT 2  - Actual Class:  MIT
# Predicted class:  ME1 2  - Actual Class:  VAC
# Predicted class:  CYT 2  - Actual Class:  VAC
# Predicted class:  ME2 2  - Actual Class:  ME1
# Predicted class:  ME3 1  - Actual Class:  MIT
# Predicted class:  ME1 2  - Actual Class:  ME1
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  ME3 1  - Actual Class:  ME3
# Predicted class:  POX 3  - Actual Class:  POX
# Predicted class:  MIT 2  - Actual Class:  ME3
# Predicted class:  NUC 2  - Actual Class:  ME3
# Predicted class:  NUC 2  - Actual Class:  ME3
# Predicted class:  ME3 2  - Actual Class:  ME3
# Predicted class:  ME3 2  - Actual Class:  ME3
# Predicted class:  ME3 2  - Actual Class:  ME3
# Predicted class:  ME3 2  - Actual Class:  ME3
# Predicted class:  MIT 2  - Actual Class:  ME2
# Predicted class:  CYT 2  - Actual Class:  NUC
# Predicted class:  ME3 2  - Actual Class:  ME3
# Predicted class:  MIT 2  - Actual Class:  CYT
# Predicted class:  NUC 3  - Actual Class:  NUC
# Predicted class:  CYT 3  - Actual Class:  CYT
# Predicted class:  CYT 2  - Actual Class:  MIT
# Predicted class:  CYT 3  - Actual Class:  MIT
# Predicted class:  CYT 3  - Actual Class:  MIT
# Predicted class:  ME3 1  - Actual Class:  ME2
# 233
# 445
# 52.359550561797754
